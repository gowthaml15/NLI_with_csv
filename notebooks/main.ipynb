# %%
import os 
from dotenv import load_dotenv
load_dotenv("../.env")
os.environ["OPENAI_API_KEY"] = os.getenv('OpenAI-API-Key')

# %% [markdown]
# ### Single csv

# %%
import pandas as pd
from pandasai import SmartDataframe

# Sample DataFrame
df = pd.read_csv("/Users/gowtham/Codes/Personal_repos/NLI_with_csv/data/Sample_Data.csv")

# Instantiate a LLM
from pandasai.llm import OpenAI
llm = OpenAI()

df = SmartDataframe(df, config={"llm": llm})
df.chat('Plot a pie chart for the top 5 patients who have the maximum invoice amount.')
# Out:
# '/Users/gowtham/Codes/Personal_repos/NLI_with_csv/exports/charts/temp_chart.png'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993 entries, 0 to 992
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   encounterID       99 non-null     float64
#  1   InvoiceID         99 non-null     float64
#  2   PatientId         99 non-null     float64
#  3   ServiceDt         99 non-null     object
#  4   Code              93 non-null     object
#  5   CPT Desc          84 non-null     object
#  6   CPTGroup          93 non-null     object
#  7   InvoiceAmount     99 non-null     float64
#  8   OrderingProvider  99 non-null     object
#  9   FacilityId        99 non-null     float64
#  10  FacilityName      99 non-null     object
#  11  insuranceName     48 non-null     object
#  12  Sex               99 non-null     object
#  13  City              99 non-null     object
# dtypes: float64(5), object(9)
# memory usage: 108.7+ KB

# %%
# Plot histogram
df.plot_histogram(column="CPT Desc")

# %% [markdown]
# ### Multiple CSV

# %%
import pandas as pd
from pandasai import SmartDatalake
from pandasai.llm import OpenAI

employees_data = {
    'EmployeeID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Emma', 'Liam', 'Olivia', 'William'],
    'Department': ['HR', 'Sales', 'IT', 'Marketing', 'Finance']
}

salaries_data = {
    'EmployeeID': [1, 2, 3, 4, 5],
    'Salary': [5000, 6000, 4500, 7000, 5500]
}

employees_df = pd.DataFrame(employees_data)
salaries_df = pd.DataFrame(salaries_data)


llm = OpenAI()
dl = SmartDatalake([employees_df, salaries_df], config={"llm": llm})
dl.chat("Who gets paid the most?")
# Out:
# 'The employee who gets paid the most is Olivia.'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Plot histogram
# ----> 2 df.plot_histogram(column="gdp")
#
# NameError: name 'df' is not defined
